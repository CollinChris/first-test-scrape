# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_listings(page):
    
    cookies = {
        'huntr_referrer': '',
        '__client_uat': '0',
        'mp_1d6f823f8d5432354b55fc0af879343c_mixpanel': '%7B%22distinct_id%22%3A%20%22%24device%3A191222c55ee1d1d-0a7a9200776677-26001e51-11a2a6-191222c55ef1d1d%22%2C%22%24device_id%22%3A%20%22191222c55ee1d1d-0a7a9200776677-26001e51-11a2a6-191222c55ef1d1d%22%2C%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D',
    }

    headers = {
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'en-US,en;q=0.5',
        # 'cookie': 'huntr_referrer=; __client_uat=0; mp_1d6f823f8d5432354b55fc0af879343c_mixpanel=%7B%22distinct_id%22%3A%20%22%24device%3A191222c55ee1d1d-0a7a9200776677-26001e51-11a2a6-191222c55ef1d1d%22%2C%22%24device_id%22%3A%20%22191222c55ee1d1d-0a7a9200776677-26001e51-11a2a6-191222c55ef1d1d%22%2C%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D',
        'priority': 'u=1, i',
        'referer': 'https://huntr.co/jobs',
        'sec-ch-ua': '"Not)A;Brand";v="99", "Brave";v="127", "Chromium";v="127"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'sec-gpc': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
    }
    
    params = {
        'page': str(page)
    }
    
    response = requests.get('https://huntr.co/public/search/job-posts', params=params, cookies=cookies, headers=headers)
    json_response = response.json()
    master_list = []
    
    for listing in json_response["results"]:
        try:
            data_dict = {}
            data_dict["id"] = listing["id"]
            data_dict["createdAt"] = listing["createdAt"]
            data_dict["remote"] = listing["isRemote"]
            data_dict["employeeCount"] = listing["employeeCount"]
            data_dict["originalTitle"] = listing["originalTitle"]
            #data_dict["places"] = listing["places"]
            data_dict["place_name"] = listing["places"][0]["name"]
            data_dict["address"] = listing["places"][0]["address"]
            data_dict["country"] = listing["places"][0]["country"]
        except:
            data_dict["id"] = ""
            data_dict["createdAt"] = ""
            data_dict["remote"] = ""
            data_dict["employeeCount"] = ""
            data_dict["originalTitle"] = ""
            #data_dict["places"] = ""
            data_dict["place_name"] = ""
            data_dict["address"] = ""
            data_dict["country"] = ""
        master_list.append(data_dict)
    df = pd.DataFrame(master_list)
    return df

# %%
for i in range(10):
    listings = get_listings(i+1)
    listing.to_csv('page_' + str(i + 1) + '.csv', index = False)

# %%
listings
# Out:
#                           id                 createdAt  remote  employeeCount  \
# 0   66ac54d0d39dc1004caaf13f  2024-08-02T03:38:56.361Z   False           1664
# 1   66ac54ccf5990a005b4883be  2024-08-02T03:38:52.730Z   False           1664
# 2   66ac54cb2881f1005299365d  2024-08-02T03:38:51.839Z   False           1664
# 3   66ac54c4210dc90054c7b344  2024-08-02T03:38:44.409Z   False           1664
# 4   66ac54a2210dc90054c7b2c1  2024-08-02T03:38:10.463Z   False           1664
# 5   66ac5478f5990a005b4882ec  2024-08-02T03:37:28.111Z   False           1664
# 6   66ac5475d39dc1004caaf029  2024-08-02T03:37:25.647Z   False            607
# 7   66ac5471f5990a005b488242  2024-08-02T03:37:21.168Z   False           1664
# 8   66ac546fd39dc1004caaefb7  2024-08-02T03:37:19.994Z   False           1664
# 9   66ac546df5990a005b4881d2  2024-08-02T03:37:17.686Z   False           1664
# 10  66ac545b210dc90054c7b201  2024-08-02T03:36:59.673Z   False           1664
# ...

# %%
listing.to_csv('page_' + (listing + 1) + '.csv', index = False)
